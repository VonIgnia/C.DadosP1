# %% [markdown]
# ### C.Dados Projeto 1
# **Análise Exploratória**

# %% [markdown]
# Após o meu feedback da APS-1 resolvi abordar outra questão, pois o Acordo de Paris (COP21) e Protocolo de Kyoto contam como tratados internacionais e não como organizações, tendo isso em vista optei por abordar a OPEC *(Organization of Petroleum Exporting Countries)*

# %% [markdown]
# "OPEC often has difficulty agreeing on policy decisions because its member countries differ widely in their oil export capacities, production costs, reserves, geological features, population, economic development, budgetary situations, and political circumstances. Indeed, over the course of market cycles, oil reserves can themselves become a source of serious conflict, instability and imbalances, in what economists call the "natural resource curse""
#
# Fonte: https://en.wikipedia.org/wiki/OPEC

# %% [markdown]
# Como mencionado na célula anterior existem grandes dissiparidades entre os países membros da OPEC, tendo isso em vista gostaria de responder à seguinte questões:
#
# - Quais indicadores socio-economicos aumentaram após os Países-membros ingressarem na OPEC?
# - Houve alguma excessão entre os países mebros em relação a algum desses indicadores?
#
# Motivo da pergunta: Dissiparidade Economica entre os membros, observando como exemplos a Venezuela, que bate recordes de inflação (53,798,500%) e os Estados Unidos que mantém esse indice abaixo de 2%

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Oil_Production= pd.read_excel("Oil Production.xlsx")
Oil_Reserves= pd.read_excel("Oil Proved reserves.xlsx")
GDPperCapita= pd.read_excel("GDPpercapitaconstant2000US.xlsx")
TotalofGDP= pd.read_excel("indicator GDP at market prices, constant 2000 US$ (WB estimates).xlsx")
ExportPofGDP= pd.read_excel("Exports (p of GDP).xlsx")

# %%
Oil_Production
# Out:
#     Crude oil production, total (toe)          1965          1966  \
# 0                            Abkhazia           NaN           NaN
# 1                         Afghanistan           NaN           NaN
# 2               Akrotiri and Dhekelia           NaN           NaN
# 3                             Albania           NaN           NaN
# 4                             Algeria  2.648100e+07  3.387200e+07
# 5                      American Samoa           NaN           NaN
# 6                             Andorra           NaN           NaN
# 7                              Angola  6.550000e+05  6.310000e+05
# 8                            Anguilla           NaN           NaN
# 9                 Antigua and Barbuda           NaN           NaN
# 10                          Argentina  1.376476e+07  1.464397e+07
# 11                            Armenia           NaN           NaN
# 12                              Aruba           NaN           NaN
# ...

# %%
Oil_Reserves
# Out:
#    Oil proved reserves total (tonnes)         1980         1981         1982  \
# 0                             Algeria   1118480000   1102112000   1287616000
# 1                              Angola    187550000    151131200    198734800
# 2                           Argentina    335134800    296213333    265925440
# 3                           Australia    289551438    357156336    330131535
# 4                          Azerbaijan            -            -            -
# 5                              Brazil    179770691    201304739    234395106
# 6                              Brunei    176501600    204600000    197132100
# 7                              Canada   1186423932   1269255376   1236511612
# 8                                Chad            -            -            -
# 9                               China   1818812815   1810345976   1806042665
# 10                           Colombia     75020000     72292000     83204000
# ...

# %%
GDPperCapita
# Out:
#     Income per person (fixed 2000 US$)          1960          1961  \
# 0                             Abkhazia           NaN           NaN
# 1                          Afghanistan           NaN           NaN
# 2                Akrotiri and Dhekelia           NaN           NaN
# 3                              Albania           NaN           NaN
# 4                              Algeria   1280.384828   1085.414612
# 5                       American Samoa           NaN           NaN
# 6                              Andorra           NaN           NaN
# 7                               Angola           NaN           NaN
# 8                             Anguilla           NaN           NaN
# 9                  Antigua and Barbuda           NaN           NaN
# 10                           Argentina   5251.876754   5448.303627
# 11                             Armenia           NaN           NaN
# 12                               Aruba           NaN           NaN
# ...

# %%
TotalofGDP
# Out:
#        GDP (constant 2000 US$)          1960          1961          1962  \
# 0                     Abkhazia           NaN           NaN           NaN
# 1                  Afghanistan           NaN           NaN           NaN
# 2        Akrotiri and Dhekelia           NaN           NaN           NaN
# 3                      Albania           NaN           NaN           NaN
# 4                      Algeria  1.382815e+10  1.194677e+10  9.595044e+09
# 5               American Samoa           NaN           NaN           NaN
# 6                      Andorra           NaN           NaN           NaN
# 7                       Angola           NaN           NaN           NaN
# 8                     Anguilla           NaN           NaN           NaN
# 9          Antigua and Barbuda           NaN           NaN           NaN
# 10                   Argentina  1.083223e+11  1.142019e+11  1.132289e+11
# 11                     Armenia           NaN           NaN           NaN
# ...

# %%
ExportPofGDP
# Out:
#     Exports of goods and services (% of GDP)       1961       1962       1963  \
# 0                                   Abkhazia        NaN        NaN        NaN
# 1                                Afghanistan   4.453443   4.878051   9.171601
# 2                      Akrotiri and Dhekelia        NaN        NaN        NaN
# 3                                    Albania        NaN        NaN        NaN
# 4                                    Algeria  46.244557  19.793872  24.684682
# 5                             American Samoa        NaN        NaN        NaN
# 6                                    Andorra        NaN        NaN        NaN
# 7                                     Angola        NaN        NaN        NaN
# 8                                   Anguilla        NaN        NaN        NaN
# 9                        Antigua and Barbuda        NaN        NaN        NaN
# 10                                 Argentina   5.994947   4.691843   7.890454
# ...

# %% [markdown]
# ## Filtrar com Países Membros da OPEC:
# Tentativa 1 - **Falhou**
# - Value Counts = apenas 1 país é detectado como membro da opec
# - criou um país opec e só aribuiu o valor sim a ele ao invés de "ler" a lista

# %%
opec =["Algeria", "Angola", "Ecuador", "Equatorial Guinea", "Gabon", "Iran", "Iraq",
      "Kuwait", "Libya", "Nigeria", "Congo, Rep.", "Saudi Arabia",
      "United Arab Emirates","Venezuela","Indonesia", "Qatar"]
formeropec=["United Arab Emirates","Venezuela","Indonesia", "Qatar"]

# %%
Oil_Production.loc[:,"OPEC"]= "não"
Oil_Production.loc["opec","OPEC"]= "sim"
Oil_Production.OPEC.value_counts()
# Out:
# não    275
# sim      1
# Name: OPEC, dtype: int64

# %%
Oil_Production
# Out:
#      Crude oil production, total (toe)          1965          1966  \
# 0                             Abkhazia           NaN           NaN
# 1                          Afghanistan           NaN           NaN
# 2                Akrotiri and Dhekelia           NaN           NaN
# 3                              Albania           NaN           NaN
# 4                              Algeria  2.648100e+07  3.387200e+07
# 5                       American Samoa           NaN           NaN
# 6                              Andorra           NaN           NaN
# 7                               Angola  6.550000e+05  6.310000e+05
# 8                             Anguilla           NaN           NaN
# 9                  Antigua and Barbuda           NaN           NaN
# 10                           Argentina  1.376476e+07  1.464397e+07
# 11                             Armenia           NaN           NaN
# 12                               Aruba           NaN           NaN
# ...

# %% [markdown]
# Tentativa 2 - **Falhou**
#
# ***Key Error***"['Algeria' 'Angola' 'Ecuador' 'Equatorial Guinea' 'Gabon' 'Iran' 'Iraq'\n 'Kuwait' 'Libya' 'Nigeria' 'Congo, Rep.' 'Saudi Arabia'\n 'United Arab Emirates' 'Venezuela' 'Indonesia' 'Qatar'] not in index"

# %%
Oil_Production.loc[:,"OPEC"]= "não"
Oil_Production.loc[opec,"OPEC"]= "sim"
Oil_Production.OPEC.value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-87c8b7f8b711> in <module>
#       1 Oil_Production.loc[:,"OPEC"]= "não"
# ----> 2 Oil_Production.loc[opec,"OPEC"]= "sim"
#       3 Oil_Production.OPEC.value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     186         else:
#     187             key = com._apply_if_callable(key, self.obj)
# --> 188         indexer = self._get_setitem_indexer(key)
#     189         self._setitem_with_indexer(indexer, value)
#     190
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     164         if isinstance(key, tuple):
#     165             try:
# --> 166                 return self._convert_tuple(key, is_setter=True)
#     167             except IndexingError:
#     168                 pass
#
# ...

# %%
opec
# Out:
# ['Algeria',
#  'Angola',
#  'Ecuador',
#  'Equatorial Guinea',
#  'Gabon',
#  'Iran',
#  'Iraq',
#  'Kuwait',
#  'Libya',
#  'Nigeria',
#  'Congo, Rep.',
#  'Saudi Arabia',
#  'United Arab Emirates',
#  'Venezuela',
#  'Indonesia',
#  'Qatar']

# %%
Oil_Production
# Out:
#      Crude oil production, total (toe)          1965          1966  \
# 0                             Abkhazia           NaN           NaN
# 1                          Afghanistan           NaN           NaN
# 2                Akrotiri and Dhekelia           NaN           NaN
# 3                              Albania           NaN           NaN
# 4                              Algeria  2.648100e+07  3.387200e+07
# 5                       American Samoa           NaN           NaN
# 6                              Andorra           NaN           NaN
# 7                               Angola  6.550000e+05  6.310000e+05
# 8                             Anguilla           NaN           NaN
# 9                  Antigua and Barbuda           NaN           NaN
# 10                           Argentina  1.376476e+07  1.464397e+07
# 11                             Armenia           NaN           NaN
# 12                               Aruba           NaN           NaN
# ...

# %% [markdown]
# Tentativa 3 - sucesso pt.1

# %%
Oil_Production_idx= Oil_Production.set_index("Crude oil production, total (toe)")
Oil_Production_idx.loc[:,"OPEC"]= 0
Oil_Production_idx.loc[opec,"OPEC"]= 1
OP=Oil_Production_idx[(Oil_Production_idx.OPEC)==1]
OP
# Out:
#                                            1965          1966          1967  \
# Crude oil production, total (toe)
# Algeria                            2.648100e+07  3.387200e+07  3.907600e+07
# Angola                             6.550000e+05  6.310000e+05  5.370000e+05
# Congo, Rep.                        7.100000e+04  6.200000e+04           NaN
# Ecuador                            4.287812e+05  3.751836e+05  3.215859e+05
# Equatorial Guinea                           NaN           NaN           NaN
# Gabon                              1.265000e+06  1.447000e+06  3.445000e+06
# Indonesia                          2.453527e+07  2.392946e+07  2.574689e+07
# Iran                               9.566209e+07  1.068929e+08  1.305076e+08
# Iraq                               6.467544e+07  6.856680e+07  6.048853e+07
# Kuwait                             1.190114e+08  1.255565e+08  1.263923e+08
# Libya                              5.798177e+07  7.166927e+07  8.236263e+07
# ...

# %%
OP.columns = OP.columns.map(lambda x: str(x))

# %% [markdown]
# Com o sucesso da tentativa 3 o processo será repetido para as outras planilhas

# %%
ExportPofGDP_idx=ExportPofGDP.set_index("Exports of goods and services (% of GDP)")
ExportPofGDP_idx.loc[:,"OPEC"]= 0
ExportPofGDP_idx.loc[opec,"OPEC"]= 1
EGDP=ExportPofGDP_idx[(ExportPofGDP_idx.OPEC)==1]
EGDP
# Out:
#                                                1961       1962       1963  \
# Exports of goods and services (% of GDP)
# Algeria                                   46.244557  19.793872  24.684682
# Angola                                          NaN        NaN        NaN
# Congo, Rep.                               19.459555  30.489597  36.472899
# Ecuador                                   16.493213  17.889721  16.246073
# Equatorial Guinea                               NaN  68.137082  62.801205
# Gabon                                     31.211693  31.714257  47.102995
# Indonesia                                 10.711047   5.812903  10.165898
# Iran                                            NaN        NaN        NaN
# Iraq                                            NaN        NaN        NaN
# Kuwait                                          NaN  64.624809  65.390280
# Libya                                           NaN        NaN        NaN
# ...

# %% [markdown]
# ## Join em determinado Ano
# Tentativa 1

# %% [markdown]
# A OPEC foi fundada em 1960, no entanto para esse ano as informações estão incompletas;
# O primeiro ano a ser estudado seria 1965, pois é o primeiro ano, para o qual possuo todas as informações de que necessito
# (Produção de Petróleo, percentual da Exportação no PIB e PIB total);
# Vou pegar os dados dos países de 5 em 5 anos, pois foi numa frequencia próxima a essas que novos países entravam

# %%
df = OP.join(EGDP, how='inner', lsuffix='Production', rsuffix='%Export')
#df.loc[:, [1965, "1965"]]

# %%
df.loc[:, [2011, "2011"]]

# %%
df
# Out:
#                                    1965Production  1966Production  \
# Crude oil production, total (toe)
# Algeria                              2.648100e+07    3.387200e+07
# Angola                               6.550000e+05    6.310000e+05
# Congo, Rep.                          7.100000e+04    6.200000e+04
# Ecuador                              4.287812e+05    3.751836e+05
# Equatorial Guinea                             NaN             NaN
# Gabon                                1.265000e+06    1.447000e+06
# Indonesia                            2.453527e+07    2.392946e+07
# Iran                                 9.566209e+07    1.068929e+08
# Iraq                                 6.467544e+07    6.856680e+07
# Kuwait                               1.190114e+08    1.255565e+08
# Libya                                5.798177e+07    7.166927e+07
# Nigeria                              1.349663e+07    2.058974e+07
# Qatar                                1.160533e+07    1.449421e+07
# ...

# %%
#join = dados.loc[(dados.region=='america_north') | (dados.region=='america_south'), ['Population','GDPcapita','surface']]
